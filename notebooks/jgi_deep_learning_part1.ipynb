# %% [markdown]
# # Material
# * Primarily from
#     * Hands-On Machine-Learning with Scikit-Learn, Keras, and Tensorflow.  Aurelion Geron.
#     * Book 2nd Edition, Code 3rd Edition
#     * https://github.com/ageron/handson-ml3.git
# * Some examples from Andrew Ng and Lawrence Moroney via Coursera/Deeplearning.

# %% [markdown]
# # Session's Content
# * Very brief Introduction to ANN
#     * Perception (scikit-learn)
#     * Multi-layer Perception (MLP) (tensorflow)
# * Introduction to Tensorflow and Keras
#     * Dense layers and Sequential model

# %% [markdown]
# # Perceptron (scikit-learn)

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron
import matplotlib.pyplot as plt

# %%
def show_boundary(X, y, model, custom_cmap=None):

    from matplotlib.colors import ListedColormap

    axes = [0, 5, 0, 2]
    x0, x1 = np.meshgrid(
        np.linspace(axes[0], axes[1], 500).reshape(-1, 1),
        np.linspace(axes[2], axes[3], 200).reshape(-1, 1),
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]
    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)

    #custom_cmap = ListedColormap(['#9898ff', '#fafab0'])

    plt.figure(figsize=(7, 3))
    plt.plot(X[y == 0, 0], X[y == 0, 1], "bs", label="Not Iris setosa")
    plt.plot(X[y == 1, 0], X[y == 1, 1], "yo", label="Iris setosa")
    plt.contourf(x0, x1, zz, cmap=custom_cmap)
    plt.xlabel("Petal length")
    plt.ylabel("Petal width")
    plt.legend(loc="lower right")
    plt.axis(axes)
    plt.show()

# %%
from pathlib import Path

IMAGES_PATH = Path() / "images" / "dse"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
def perceptron_sklearn_example():
    #=====================================================#
    # Load data, will be numpy arrays
    #=====================================================#
    iris = load_iris()
    X = iris.data[:,(2,3)] # petal length, petal width
    y = (iris.target == 0).astype(int) # iris setosa?

    #=====================================================#
    # Create model
    #=====================================================#
    model = Perceptron()
    model.fit(X,y)

    #=====================================================#
    # Predict (more generally evaluate)
    #=====================================================#
    y_pred = model.predict( [[2.0, 0.25]] )
    print(y_pred)

    #=====================================================#
    # Understanding, visualize model predictions
    #=====================================================#
    show_boundary(X, y, model)
perceptron_sklearn_example()
# Out:
# [1]

# %% [markdown]
# ## Discussion:
# * In what sense Perceptron is similar Logistic Regression?
# * What would be the main difference?
#
# * What about multiple units?
# * What about multiple layers?
# * What about different activation functions?
# * What about different loss functions?

# %% [markdown]
# # Multi-Layer Perceptron (MLP)
# MLP is a type of "feed-forward neural network".
# * Can learn non-linear boundaries using different activation functions
# * Multi-classification using soft-max activation function at output layer

# %% [markdown]
# # Activation Functions
# Without non-linear activation functions, neural networks are reduced to finding linear boundaries.  Activation functions are involved in backpropagation that uses gradient of the function to determine how weights need to be changed to minimise the loss function.  Therefore, activation functions need to be differentiable (where evaluated).  Common activation functions are (see https://www.tensorflow.org/api_docs/python/tf/keras/activations):
#
# * sigmoid
# * relu
# * softmax
# * tanh
# * linear
#
# Extensive research has been conducted on various activation functions.  The output layer activation function depends on the problem (e.g. softmax for multi-classification, cross-entropy for binary classification, linear for regression).  For the hidden layers, however, rule of thumb is to use the **relu** activation function.  The function and the deriviative are both trivial making training and predictions computationally faster with good learning rates for many problems. Though this does restrict the output to be positive which may not be suitable for certain problems (e.g. regression problem that needs to predict negative values).

# %%
def show_activations():
    # extra code – this cell generates and saves Figure 10–8

    from scipy.special import expit as sigmoid

    def relu(z):
        return np.maximum(0, z)

    def derivative(f, z, eps=0.000001):
        return (f(z + eps) - f(z - eps))/(2 * eps)

    max_z = 4.5
    z = np.linspace(-max_z, max_z, 200)

    plt.figure(figsize=(11, 3.1))

    plt.subplot(121)
    plt.plot([-max_z, 0], [0, 0], "r-", linewidth=2, label="Heaviside")
    plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
    plt.plot([0, 0], [0, 1], "r-", linewidth=0.5)
    plt.plot([0, max_z], [1, 1], "r-", linewidth=2)
    plt.plot(z, sigmoid(z), "g--", linewidth=2, label="Sigmoid")
    plt.plot(z, np.tanh(z), "b-", linewidth=1, label="Tanh")
    plt.grid(True)
    plt.title("Activation functions")
    plt.axis([-max_z, max_z, -1.65, 2.4])
    plt.gca().set_yticks([-1, 0, 1, 2])
    plt.legend(loc="lower right", fontsize=13)

    plt.subplot(122)
    plt.plot(z, derivative(np.sign, z), "r-", linewidth=2, label="Heaviside")
    plt.plot(0, 0, "ro", markersize=5)
    plt.plot(0, 0, "rx", markersize=10)
    plt.plot(z, derivative(sigmoid, z), "g--", linewidth=2, label="Sigmoid")
    plt.plot(z, derivative(np.tanh, z), "b-", linewidth=1, label="Tanh")
    plt.plot([-max_z, 0], [0, 0], "m-.", linewidth=2)
    plt.plot([0, max_z], [1, 1], "m-.", linewidth=2)
    plt.plot([0, 0], [0, 1], "m-.", linewidth=1.2)
    plt.plot(0, 1, "mo", markersize=5)
    plt.plot(0, 1, "mx", markersize=10)
    plt.grid(True)
    plt.title("Derivatives")
    plt.axis([-max_z, max_z, -0.2, 1.2])

    save_fig("activation_functions_plot")
    plt.show()
show_activations()

# %% [markdown]
# # Deep Learning
# What about many more hidden layers betweenn input and output layers?  Definitely more computationally difficult to train.  Any advantages?  Yes!  With careful design multiple layers can "learn higher level" features.  This is known as feature learning and has been tremendous area of research and successful applications.

# %% [markdown]
# # Tensorflow
# Why do we need tensorflow?
# * What about multiple units?
# * What about multiple layers?
# * What about different activation functions?
# * How do we create more complex models?
#
# Answer: Deep learning framework
#
# Why not just use existing libraries to provide framework?  Theano built on numpy. However, progress has been made with libraries using specialised vector representations (often referred to as tensors).  Some common deep learning frameworks include...
#
# * Tensorflow
# * PyTorch
# * CNTK
# * Caffe
# * Theano (though not actively maintained)
#
# We use Tensorflow 2.0 here, however, PyTorch is a very strong contender.  A little good news is that learning Tensorflow makes learning PyTorch easier (and visa versa).

# %% [markdown]
# # Tensorflow Architecture
#
# Tensorflow ...
#
# * Numerical library based on Eigen, CUDA, NVidia cuDNN
# * CUDA provides access to GPU for fast linear algebra implementations
# * Specialised hardware orders of magnitude faster than software implementations
# * But also, common layers, models, activation, loss functions...
# * But also, implementation of backpropagation to learn gradients
# * Mostly written in C++
#
# We have to use C++ to use Tensorflow?
# * No.  You can but  API's for many languages, Python, Java, Go, etc.

# %% [markdown]
# # Keras
#
# What is Keras?
#
# * Keras is an API to Deep Learning Framework(s)
# * Provides simplified access to Tensorflow
# * Used to support other DL frameworks: Theano, CNTK
# * Intended to make porting to different DL frameworks easy
# * Makes model specification easier
# * PyTorch (sadly) is not supported as a backend
#
# Keras is the default Python API to TF2.  Keras is installed when you install TF.  Let's see a picture...

# %% [markdown]
# # Tensorflow 2.0

# %% [markdown]
# # Perceptron (tensorflow)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy

# %%
def perceptron_tf():
    #=====================================================#
    # Load data, will be numpy arrays
    #=====================================================#
    iris = load_iris()
    X = iris.data[:,(2,3)] # petal length, petal width
    y = (iris.target == 0).astype(int) # iris setosa?

    #=====================================================#
    # Create model
    #=====================================================#
    layer1 = Dense(units=1, activation="sigmoid") # defaults to bias=True
    model = Sequential( layer1 )
    model.compile( optimizer="sgd", loss=BinaryCrossentropy() )
    model.fit(X,y)

    #=====================================================#
    # Evaluate, predictions produce probability because BinaryCrossentropy
    # Note that decision boundary is different than Perceptron
    #=====================================================#
    y_pred_prob = model.predict( [[2, 0.25]] )
    # Make "hard decision", y_pred_prob = [[0.321719]]
    if y_pred_prob[0][0] < 0.5:
        y_pred = 0
    else:
        y_pred = 1
    print(f"y_pred_prob={y_pred_prob} y_pred={y_pred}")

    #=====================================================#
    # Understanding, visualize model predictions
    #=====================================================#
    show_boundary(X, y, model)
perceptron_tf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9fa6f15d0f44> in <cell line: 33>()
#      31     #=====================================================#
#      32     show_boundary(X, y, model)
# ---> 33 perceptron_tf()
#
# <ipython-input-11-9fa6f15d0f44> in perceptron_tf()
#      11     #=====================================================#
#      12     layer1 = Dense(units=1, activation="sigmoid") # defaults to bias=True
# ---> 13     model = Sequential( layer1 )
#      14     model.compile( optimizer="sgd", loss=BinaryCrossentropy() )
#      15     model.fit(X,y)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      70         self._layers = []
#      71         if layers:
# ---> 72             for layer in layers:
#      73                 self.add(layer, rebuild=False)
#      74             self._maybe_rebuild()
#
# TypeError: 'Dense' object is not iterable

# %%
def perceptron_tf():
    #=====================================================#
    # Load data, will be numpy arrays
    #=====================================================#
    iris = load_iris()
    X = iris.data[:,(2,3)] # petal length, petal width
    y = (iris.target == 0).astype(int) # iris setosa?

    #=====================================================#
    # Create model
    #=====================================================#
    layer1 = Dense(units=1, activation="sigmoid") # defaults to bias=True
    # Enclose the layer1 in a list when passing to Sequential
    model = Sequential( [layer1] )
    model.compile( optimizer="sgd", loss=BinaryCrossentropy() )
    model.fit(X,y)

    #=====================================================#
    # Evaluate, predictions produce probability because BinaryCrossentropy
    # Note that decision boundary is different than Perceptron
    #=====================================================#
    # Convert the input to a NumPy array before prediction
    import numpy as np  # Import numpy if not already imported
    y_pred_prob = model.predict( np.array([[2, 0.25]]) )
    # Make "hard decision", y_pred_prob = [[0.321719]]
    if y_pred_prob[0][0] < 0.5:
        y_pred = 0
    else:
        y_pred = 1
    print(f"y_pred_prob={y_pred_prob} y_pred={y_pred}")

    #=====================================================#
    # Understanding, visualize model predictions
    #=====================================================#
    show_boundary(X, y, model)
perceptron_tf()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# y_pred_prob=[[0.40407225]] y_pred=0
# 10863/10863 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step

# %% [markdown]
# ## Discussion:
# How this result is different from the previous MLP results?

# %% [markdown]
# # Simple Regression Example with Tensorflow
# We will create a dataset with a simple linear relationship between one x feature and the y target. Do not necessarily need tensorflow for this specific example but can certainly extend.  In fact, recurrent neural networks (RNNs) are competitive with traditional time series approaches, such as ARIMA models.

# %%
def regression_example():
    #=====================================================#
    # Define the training data: input xs and answers ys
    # dtype clue that TF is not python because most tf.types are c++, not python types
    # The function (aka rule) to map x -> y, y = 2x - 1
    #=====================================================#
    import numpy as np
    xs = np.array( [-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float )
    ys = np.array( [-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float )

    #=====================================================#
    # Create model, the input is one data value, model has one neuron, output is one value.
    # All models in TF must have an optimizer and a loss function
    #=====================================================#
    model = keras.Sequential( [keras.layers.Dense(units=1, activation="linear", input_shape=[1])] )
    model.compile( optimizer="sgd", loss="mean_squared_error" )
    # Learn the function that maps x to y
    # Iterate enough times, more usually means better approximation too true function
    model.fit( xs, ys, epochs=500 )

    #=====================================================#
    # Evaluate the model to see how well it learned the function
    #=====================================================#
    import numpy as np  # Import numpy if not already imported
    print( model.predict(np.array([10.0])) )
    # print( model.predict([10.0]) )
regression_example()
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 8.4098
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.8168
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.5593
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.5660
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 3.7805
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.1587
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.6657
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.2741
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.9624
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7136
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5144
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3542
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2249
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.1198
# Epoch 15/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0340
# Epoch 16/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.9633
# Epoch 17/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9046
# Epoch 18/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8554
# Epoch 19/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.8138
# Epoch 20/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.7781
# Epoch 21/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.7472
# Epoch 22/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.7201
# Epoch 23/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.6961
# Epoch 24/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.6746
# Epoch 25/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.6550
# Epoch 26/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6371
# Epoch 27/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.6204
# Epoch 28/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.6049
# Epoch 29/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5903
# Epoch 30/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5765
# Epoch 31/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5633
# Epoch 32/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.5506
# Epoch 33/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5385
# Epoch 34/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5268
# Epoch 35/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.5154
# Epoch 36/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.5044
# Epoch 37/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4937
# Epoch 38/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.4833
# Epoch 39/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4732
# Epoch 40/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4633
# Epoch 41/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.4537
# Epoch 42/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4443
# Epoch 43/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4351
# Epoch 44/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.4261
# Epoch 45/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.4173
# Epoch 46/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4087
# Epoch 47/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.4003
# Epoch 48/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3920
# Epoch 49/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3839
# Epoch 50/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3760
# Epoch 51/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3683
# Epoch 52/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3607
# Epoch 53/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3533
# Epoch 54/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3461
# Epoch 55/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3389
# Epoch 56/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3320
# Epoch 57/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3252
# Epoch 58/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3185
# Epoch 59/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3119
# Epoch 60/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3055
# Epoch 61/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2992
# Epoch 62/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2931
# Epoch 63/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2871
# Epoch 64/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2812
# Epoch 65/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2754
# Epoch 66/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2697
# Epoch 67/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2642
# Epoch 68/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2588
# Epoch 69/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2535
# Epoch 70/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2483
# Epoch 71/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2432
# Epoch 72/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2382
# Epoch 73/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2333
# Epoch 74/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2285
# Epoch 75/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2238
# Epoch 76/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2192
# Epoch 77/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2147
# Epoch 78/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2103
# Epoch 79/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2060
# Epoch 80/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2017
# Epoch 81/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1976
# Epoch 82/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1935
# Epoch 83/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1895
# Epoch 84/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1857
# Epoch 85/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1818
# Epoch 86/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1781
# Epoch 87/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1744
# Epoch 88/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1709
# Epoch 89/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1674
# Epoch 90/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1639
# Epoch 91/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1606
# Epoch 92/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1573
# Epoch 93/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1540
# Epoch 94/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1509
# Epoch 95/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1478
# Epoch 96/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1447
# Epoch 97/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1418
# Epoch 98/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1388
# Epoch 99/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1360
# Epoch 100/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1332
# Epoch 101/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1305
# Epoch 102/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1278
# Epoch 103/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1252
# Epoch 104/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1226
# Epoch 105/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1201
# Epoch 106/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1176
# Epoch 107/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1152
# Epoch 108/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1128
# Epoch 109/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1105
# Epoch 110/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1082
# Epoch 111/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1060
# Epoch 112/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1038
# Epoch 113/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1017
# Epoch 114/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0996
# Epoch 115/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0976
# Epoch 116/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0956
# Epoch 117/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0936
# Epoch 118/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0917
# Epoch 119/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0898
# Epoch 120/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0879
# Epoch 121/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0861
# Epoch 122/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0844
# Epoch 123/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0826
# Epoch 124/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0809
# Epoch 125/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0793
# Epoch 126/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0776
# Epoch 127/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0761
# Epoch 128/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0745
# Epoch 129/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0730
# Epoch 130/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0715
# Epoch 131/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0700
# Epoch 132/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0686
# Epoch 133/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0671
# Epoch 134/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0658
# Epoch 135/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0644
# Epoch 136/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0631
# Epoch 137/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0618
# Epoch 138/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0605
# Epoch 139/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0593
# Epoch 140/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0581
# Epoch 141/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0569
# Epoch 142/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0557
# Epoch 143/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0546
# Epoch 144/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0534
# Epoch 145/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0523
# Epoch 146/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0513
# Epoch 147/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0502
# Epoch 148/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0492
# Epoch 149/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0482
# Epoch 150/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0472
# Epoch 151/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0462
# Epoch 152/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0453
# Epoch 153/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0443
# Epoch 154/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0434
# Epoch 155/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0425
# Epoch 156/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0417
# Epoch 157/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0408
# Epoch 158/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0400
# Epoch 159/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0391
# Epoch 160/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0383
# Epoch 161/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0376
# Epoch 162/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0368
# Epoch 163/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0360
# Epoch 164/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0353
# Epoch 165/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0346
# Epoch 166/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0339
# Epoch 167/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0332
# Epoch 168/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0325
# Epoch 169/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0318
# Epoch 170/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0312
# Epoch 171/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0305
# Epoch 172/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0299
# Epoch 173/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0293
# Epoch 174/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0287
# Epoch 175/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0281
# Epoch 176/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0275
# Epoch 177/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0269
# Epoch 178/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0264
# Epoch 179/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0258
# Epoch 180/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0253
# Epoch 181/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0248
# Epoch 182/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0243
# Epoch 183/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0238
# Epoch 184/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0233
# Epoch 185/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0228
# Epoch 186/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0224
# Epoch 187/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0219
# Epoch 188/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0214
# Epoch 189/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0210
# Epoch 190/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0206
# Epoch 191/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0201
# Epoch 192/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0197
# Epoch 193/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0193
# Epoch 194/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0189
# Epoch 195/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0185
# Epoch 196/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0182
# Epoch 197/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0178
# Epoch 198/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0174
# Epoch 199/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0171
# Epoch 200/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0167
# Epoch 201/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0164
# Epoch 202/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0160
# Epoch 203/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0157
# Epoch 204/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0154
# Epoch 205/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0151
# Epoch 206/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0148
# Epoch 207/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0145
# Epoch 208/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0142
# Epoch 209/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0139
# Epoch 210/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0136
# Epoch 211/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0133
# Epoch 212/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0130
# Epoch 213/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0128
# Epoch 214/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0125
# Epoch 215/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0122
# Epoch 216/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0120
# Epoch 217/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0117
# Epoch 218/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0115
# Epoch 219/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0113
# Epoch 220/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0110
# Epoch 221/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0108
# Epoch 222/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0106
# Epoch 223/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0104
# Epoch 224/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0102
# Epoch 225/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0099
# Epoch 226/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0097
# Epoch 227/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0095
# Epoch 228/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0093
# Epoch 229/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0092
# Epoch 230/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0090
# Epoch 231/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0088
# Epoch 232/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0086
# Epoch 233/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0084
# Epoch 234/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0083
# Epoch 235/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0081
# Epoch 236/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0079
# Epoch 237/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0078
# Epoch 238/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0076
# Epoch 239/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0074
# Epoch 240/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0073
# Epoch 241/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0071
# Epoch 242/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0070
# Epoch 243/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0068
# Epoch 244/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0067
# Epoch 245/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0066
# Epoch 246/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0064
# Epoch 247/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0063
# Epoch 248/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0062
# Epoch 249/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0060
# Epoch 250/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0059
# Epoch 251/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0058
# Epoch 252/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0057
# Epoch 253/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0056
# Epoch 254/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0055
# Epoch 255/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0053
# Epoch 256/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0052
# Epoch 257/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0051
# Epoch 258/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0050
# Epoch 259/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0049
# Epoch 260/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0048
# Epoch 261/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0047
# Epoch 262/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0046
# Epoch 263/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0045
# Epoch 264/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0044
# Epoch 265/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0043
# Epoch 266/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0042
# Epoch 267/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0042
# Epoch 268/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0041
# Epoch 269/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0040
# Epoch 270/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0039
# Epoch 271/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0038
# Epoch 272/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038
# Epoch 273/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0037
# Epoch 274/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0036
# Epoch 275/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0035
# Epoch 276/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0035
# Epoch 277/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0034
# Epoch 278/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0033
# Epoch 279/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0032
# Epoch 280/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0032
# Epoch 281/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0031
# Epoch 282/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030
# Epoch 283/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0030
# Epoch 284/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0029
# Epoch 285/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0029
# Epoch 286/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0028
# Epoch 287/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0027
# Epoch 288/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0027
# Epoch 289/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0026
# Epoch 290/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0026
# Epoch 291/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025
# Epoch 292/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0025
# Epoch 293/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0024
# Epoch 294/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024
# Epoch 295/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023
# Epoch 296/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0023
# Epoch 297/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022
# Epoch 298/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0022
# Epoch 299/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021
# Epoch 300/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021
# Epoch 301/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0021
# Epoch 302/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0020
# Epoch 303/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0020
# Epoch 304/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0019
# Epoch 305/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0019
# Epoch 306/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0019
# Epoch 307/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0018
# Epoch 308/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0018
# Epoch 309/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0017
# Epoch 310/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0017
# Epoch 311/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0017
# Epoch 312/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0016
# Epoch 313/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0016
# Epoch 314/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0016
# Epoch 315/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0015
# Epoch 316/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0015
# Epoch 317/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0015
# Epoch 318/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0014
# Epoch 319/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0014
# Epoch 320/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0014
# Epoch 321/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0014
# Epoch 322/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0013
# Epoch 323/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0013
# Epoch 324/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0013
# Epoch 325/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0012
# Epoch 326/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0012
# Epoch 327/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0012
# Epoch 328/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0012
# Epoch 329/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011
# Epoch 330/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0011
# Epoch 331/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0011
# Epoch 332/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0011
# Epoch 333/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0011
# Epoch 334/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0010
# Epoch 335/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0010
# Epoch 336/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 9.9378e-04
# Epoch 337/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 9.7337e-04
# Epoch 338/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 9.5337e-04
# Epoch 339/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 9.3379e-04
# Epoch 340/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 9.1461e-04
# Epoch 341/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.9582e-04
# Epoch 342/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.7742e-04
# Epoch 343/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.5940e-04
# Epoch 344/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 8.4174e-04
# Epoch 345/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 8.2445e-04
# Epoch 346/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 8.0752e-04
# Epoch 347/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 7.9093e-04
# Epoch 348/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.7469e-04
# Epoch 349/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.5877e-04
# Epoch 350/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.4319e-04
# Epoch 351/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.2792e-04
# Epoch 352/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.1297e-04
# Epoch 353/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 6.9833e-04
# Epoch 354/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 6.8398e-04
# Epoch 355/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6.6993e-04
# Epoch 356/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.5617e-04
# Epoch 357/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6.4269e-04
# Epoch 358/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 6.2949e-04
# Epoch 359/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 6.1656e-04
# Epoch 360/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.0390e-04
# Epoch 361/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.9149e-04
# Epoch 362/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.7934e-04
# Epoch 363/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.6744e-04
# Epoch 364/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 5.5579e-04
# Epoch 365/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 5.4437e-04
# Epoch 366/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 5.3319e-04
# Epoch 367/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 5.2224e-04
# Epoch 368/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 5.1151e-04
# Epoch 369/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 5.0101e-04
# Epoch 370/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 4.9072e-04
# Epoch 371/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 4.8064e-04
# Epoch 372/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 4.7077e-04
# Epoch 373/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.6110e-04
# Epoch 374/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 4.5162e-04
# Epoch 375/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.4235e-04
# Epoch 376/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.3326e-04
# Epoch 377/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 4.2436e-04
# Epoch 378/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.1565e-04
# Epoch 379/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.0711e-04
# Epoch 380/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.9875e-04
# Epoch 381/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.9056e-04
# Epoch 382/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.8253e-04
# Epoch 383/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.7468e-04
# Epoch 384/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.6698e-04
# Epoch 385/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.5944e-04
# Epoch 386/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 3.5206e-04
# Epoch 387/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.4483e-04
# Epoch 388/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.3775e-04
# Epoch 389/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.3081e-04
# Epoch 390/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.2401e-04
# Epoch 391/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.1736e-04
# Epoch 392/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.1084e-04
# Epoch 393/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 3.0446e-04
# Epoch 394/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.9820e-04
# Epoch 395/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 2.9208e-04
# Epoch 396/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.8608e-04
# Epoch 397/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.8020e-04
# Epoch 398/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.7445e-04
# Epoch 399/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.6881e-04
# Epoch 400/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6329e-04
# Epoch 401/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2.5788e-04
# Epoch 402/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.5258e-04
# Epoch 403/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.4739e-04
# Epoch 404/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.4231e-04
# Epoch 405/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.3734e-04
# Epoch 406/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.3246e-04
# Epoch 407/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.2769e-04
# Epoch 408/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.2301e-04
# Epoch 409/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.1843e-04
# Epoch 410/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.1394e-04
# Epoch 411/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.0955e-04
# Epoch 412/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.0524e-04
# Epoch 413/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.0103e-04
# Epoch 414/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9690e-04
# Epoch 415/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.9285e-04
# Epoch 416/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.8889e-04
# Epoch 417/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.8501e-04
# Epoch 418/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.8121e-04
# Epoch 419/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.7749e-04
# Epoch 420/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.7384e-04
# Epoch 421/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.7027e-04
# Epoch 422/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.6677e-04
# Epoch 423/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.6335e-04
# Epoch 424/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.5999e-04
# Epoch 425/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.5671e-04
# Epoch 426/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.5349e-04
# Epoch 427/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.5034e-04
# Epoch 428/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.4725e-04
# Epoch 429/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.4423e-04
# Epoch 430/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.4126e-04
# Epoch 431/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3836e-04
# Epoch 432/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3552e-04
# Epoch 433/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3274e-04
# Epoch 434/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.3001e-04
# Epoch 435/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.2734e-04
# Epoch 436/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.2472e-04
# Epoch 437/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2216e-04
# Epoch 438/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1965e-04
# Epoch 439/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1719e-04
# Epoch 440/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1479e-04
# Epoch 441/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1243e-04
# Epoch 442/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1012e-04
# Epoch 443/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.0786e-04
# Epoch 444/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0564e-04
# Epoch 445/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0347e-04
# Epoch 446/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0135e-04
# Epoch 447/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 9.9264e-05
# Epoch 448/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.7225e-05
# Epoch 449/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 9.5228e-05
# Epoch 450/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 9.3271e-05
# Epoch 451/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 9.1356e-05
# Epoch 452/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.9480e-05
# Epoch 453/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 8.7641e-05
# Epoch 454/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 8.5840e-05
# Epoch 455/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 8.4077e-05
# Epoch 456/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 8.2351e-05
# Epoch 457/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.0658e-05
# Epoch 458/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.9002e-05
# Epoch 459/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 7.7380e-05
# Epoch 460/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.5790e-05
# Epoch 461/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.4234e-05
# Epoch 462/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.2708e-05
# Epoch 463/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.1214e-05
# Epoch 464/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6.9752e-05
# Epoch 465/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.8320e-05
# Epoch 466/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6.6917e-05
# Epoch 467/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.5542e-05
# Epoch 468/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6.4197e-05
# Epoch 469/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 6.2877e-05
# Epoch 470/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.1587e-05
# Epoch 471/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.0322e-05
# Epoch 472/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.9083e-05
# Epoch 473/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.7869e-05
# Epoch 474/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.6681e-05
# Epoch 475/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 5.5515e-05
# Epoch 476/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.4375e-05
# Epoch 477/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.3257e-05
# Epoch 478/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.2165e-05
# Epoch 479/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.1093e-05
# Epoch 480/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0044e-05
# Epoch 481/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.9015e-05
# Epoch 482/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.8008e-05
# Epoch 483/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 4.7023e-05
# Epoch 484/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.6057e-05
# Epoch 485/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 4.5111e-05
# Epoch 486/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.4184e-05
# Epoch 487/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.3277e-05
# Epoch 488/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 4.2389e-05
# Epoch 489/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.1518e-05
# Epoch 490/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 4.0665e-05
# Epoch 491/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.9830e-05
# Epoch 492/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 3.9011e-05
# Epoch 493/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.8210e-05
# Epoch 494/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.7426e-05
# Epoch 495/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.6657e-05
# Epoch 496/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.5903e-05
# Epoch 497/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.5167e-05
# Epoch 498/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4444e-05
# Epoch 499/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 3.3737e-05
# Epoch 500/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.3043e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [[18.983229]]

# %% [markdown]
# #Discussion:
# * What do you think about the accuracy of the refresssion model? Is the number of epochs approriate for this problem?

# %% [markdown]
# # Image Classification Example
# We consider an image multi-classification example.  This model is somewhat simpler than convolutional neural networks (CNNs) that perform very well for this task.  However, it still performs well and is our first example where we have more than one hidden layer.  More generally, this type of model is known as a "feed forward neural network".
#
# There are a large number of parameters (i.e. weights) to learn.  Allows model flexibility to fit the data better, however, this can lead to "overfitting".  Overfitting is undesirable because it fits the training data well but does poorly on the test data.  The test data is a proxy for generalising to unseen data.  So overfitting means the model will not generarlise.

# %% [markdown]
# # Fashion MNIST Example

# %%
# helper functions
def show_image( image ):
    plt.imshow(image, cmap="binary")
    plt.axis('off')
    plt.show()

def show_predicted( X_new, y_test, class_names):
    # extra code – this cell generates and saves Figure 10–12
    plt.figure(figsize=(7.2, 2.4))
    for index, image in enumerate(X_new):
        plt.subplot(1, len(y_test), index + 1)
        plt.imshow(image, cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_test[index]])
    plt.subplots_adjust(wspace=0.3, hspace=0.5)
    save_fig('fashion_mnist_images_plot', tight_layout=False)
    plt.show()

def show_history( history, num_epochs ):
    import matplotlib.pyplot as plt
    import pandas as pd

    pd.DataFrame(history.history).plot(
        figsize=(8, 5), xlim=[0, num_epochs-1], ylim=[0, 1], grid=True, xlabel="Epoch",
        style=["r--", "r--.", "b-", "b-*"])
    plt.legend(loc="lower left")  # extra code
    save_fig("keras_learning_curves_plot")  # extra code
    plt.show()

# %%
def fashion_example():
    #=====================================================#
    # Load data, will be numpy arrays
    #=====================================================#
    fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
    (X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
    X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
    X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
    # Scale down pixel values to float in [0.0,1.0]
    X_train, X_valid, X_test = X_train / 255.0, X_valid / 255.0, X_test / 255.0

    show_image(X_train[0])

    class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

    #=====================================================#
    # Create model
    #=====================================================#
    tf.random.set_seed(42)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape=[28, 28]))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(300, activation="relu"))
    model.add(tf.keras.layers.Dense(100, activation="relu"))
    model.add(tf.keras.layers.Dense(10, activation="softmax"))

    num_epochs = 10
    model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
    history = model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
    print(history.params)
    show_history( history, num_epochs )


    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    print( model.evaluate(X_test, y_test) )
    X_new = X_test[:10]
    y_new = y_test[:10]
    y_proba = model.predict(X_new)
    y_proba.round(2)
    y_pred = y_proba.argmax(axis=-1)
    print(np.array(class_names)[y_pred]) # print what was predicted
    show_predicted(X_new, y_new, class_names)


    #=====================================================#
    # Understanding, visualize model predictions
    #=====================================================#
    # basic way to visualize the model
    print( "Model Summary" )
    print( model.summary() )
fashion_example()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6730 - loss: 1.0362 - val_accuracy: 0.8238 - val_loss: 0.5142
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.8253 - loss: 0.5113 - val_accuracy: 0.8376 - val_loss: 0.4580
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8417 - loss: 0.4540 - val_accuracy: 0.8462 - val_loss: 0.4313
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8525 - loss: 0.4216 - val_accuracy: 0.8510 - val_loss: 0.4126
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8603 - loss: 0.3989 - val_accuracy: 0.8554 - val_loss: 0.3985
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8659 - loss: 0.3813 - val_accuracy: 0.8618 - val_loss: 0.3889
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8709 - loss: 0.3669 - val_accuracy: 0.8662 - val_loss: 0.3787
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8753 - loss: 0.3543 - val_accuracy: 0.8670 - val_loss: 0.3709
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8785 - loss: 0.3436 - val_accuracy: 0.8694 - val_loss: 0.3651
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8825 - loss: 0.3337 - val_accuracy: 0.8694 - val_loss: 0.3607
# {'verbose': 'auto', 'epochs': 10, 'steps': 1719}
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8607 - loss: 0.3925
# [0.3933858871459961, 0.8597000241279602]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# ['Ankle boot' 'Pullover' 'Trouser' 'Trouser' 'Shirt' 'Trouser' 'Coat'
#  'Shirt' 'Sandal' 'Sneaker']
# Model Summary
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 300)                 │         235,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 100)                 │          30,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 266,612 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# None

# %% [markdown]
# ##Discussion:
# * How many layers in this classifier? What type of network it is?
# * Do you see any biases?
# * What is your observation on training and validation accuracy?

# %% [markdown]
# # Regression MLP
# Let's create a more complicated regression model based on the MLP.  Again, the output layer will be one unit with a linear activation function.  The inner layers can have different activations functions (again choose relu for the hidden layers).  The regression problem is to predict California housing prices.  We create the Sequential model but this time by passing a list of layers when we create the model instead of via the model.add(layer) function.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
def regression_mlp():
    #=====================================================#
    # Load data, load and split the California housing dataset, like earlier
    #=====================================================#
    housing = fetch_california_housing()
    X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

    #=====================================================#
    # Create model
    #=====================================================#
    tf.random.set_seed(42)
    norm_layer = tf.keras.layers.Normalization(input_shape=X_train.shape[1:])
    model = tf.keras.Sequential([
        norm_layer,
        tf.keras.layers.Dense(50, activation="relu"),
        tf.keras.layers.Dense(50, activation="relu"),
        tf.keras.layers.Dense(50, activation="relu"),
        tf.keras.layers.Dense(1)
    ])
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
    norm_layer.adapt(X_train)
    history = model.fit(X_train, y_train, epochs=20,
                        validation_data=(X_valid, y_valid))


    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    mse_test, rmse_test = model.evaluate(X_test, y_test)
    X_new = X_test[:3]
    y_pred = model.predict(X_new)
    print("MSE on test set")
    print( rmse_test )
    print("Predictions on several houses")
    print( y_pred )
    print("Input shape")
    print(X_train.shape[1:])
    print( "Model Summary" )
    print( model.summary() )

regression_mlp()
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - RootMeanSquaredError: 1.2340 - loss: 1.6267 - val_RootMeanSquaredError: 0.6457 - val_loss: 0.4169
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - RootMeanSquaredError: 0.6402 - loss: 0.4104 - val_RootMeanSquaredError: 0.7621 - val_loss: 0.5808
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - RootMeanSquaredError: 0.6089 - loss: 0.3711 - val_RootMeanSquaredError: 1.0150 - val_loss: 1.0303
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.5986 - loss: 0.3585 - val_RootMeanSquaredError: 0.7236 - val_loss: 0.5236
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.5874 - loss: 0.3452 - val_RootMeanSquaredError: 0.9304 - val_loss: 0.8656
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.5796 - loss: 0.3361 - val_RootMeanSquaredError: 0.7489 - val_loss: 0.5608
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5701 - loss: 0.3251 - val_RootMeanSquaredError: 0.5850 - val_loss: 0.3423
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5597 - loss: 0.3134 - val_RootMeanSquaredError: 0.5436 - val_loss: 0.2955
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5529 - loss: 0.3058 - val_RootMeanSquaredError: 0.5710 - val_loss: 0.3260
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5463 - loss: 0.2985 - val_RootMeanSquaredError: 0.5351 - val_loss: 0.2863
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5432 - loss: 0.2951 - val_RootMeanSquaredError: 0.5594 - val_loss: 0.3130
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.5366 - loss: 0.2880 - val_RootMeanSquaredError: 0.5297 - val_loss: 0.2806
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5330 - loss: 0.2842 - val_RootMeanSquaredError: 0.5318 - val_loss: 0.2828
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5295 - loss: 0.2804 - val_RootMeanSquaredError: 0.5299 - val_loss: 0.2808
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5261 - loss: 0.2768 - val_RootMeanSquaredError: 0.5741 - val_loss: 0.3296
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5244 - loss: 0.2750 - val_RootMeanSquaredError: 0.5639 - val_loss: 0.3180
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5221 - loss: 0.2727 - val_RootMeanSquaredError: 0.7069 - val_loss: 0.4997
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5194 - loss: 0.2698 - val_RootMeanSquaredError: 0.5217 - val_loss: 0.2722
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5198 - loss: 0.2702 - val_RootMeanSquaredError: 0.7531 - val_loss: 0.5671
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5181 - loss: 0.2685 - val_RootMeanSquaredError: 0.7600 - val_loss: 0.5776
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - RootMeanSquaredError: 0.5319 - loss: 0.2830
# WARNING:tensorflow:5 out of the last 10867 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cf09121d870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# MSE on test set
# 0.536169171333313
# Predictions on several houses
# [[0.5168907]
#  [1.1587491]
#  [5.131462 ]]
# Input shape
# (8,)
# Model Summary
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization)      │ (None, 8)                   │              17 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 50)                  │             450 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 50)                  │           2,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,822 (65.72 KB)
#  Trainable params: 5,601 (21.88 KB)
#  Non-trainable params: 17 (72.00 B)
#  Optimizer params: 11,204 (43.77 KB)
# None

# %% [markdown]
# ## Discussion:
# * What is your observation on prediction of this model?

# %% [markdown]
# # Regression Sequential

# %% [markdown]
# Example that predicts price of a house as before using the sequential model.  Slightly simplified to compare against the functional model.

# %%
# extra code – reset the name counters and make the code reproducible
tf.keras.backend.clear_session()
tf.random.set_seed(42)

def regression_sequential():
    #=====================================================#
    # Load data, load and split the California housing dataset, like earlier
    #=====================================================#
    housing = fetch_california_housing()
    X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

    #=====================================================#
    # Create model
    #=====================================================#
    model = tf.keras.Sequential([
        tf.keras.layers.Normalization(input_shape=X_train.shape[1:]),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(30, activation="relu"),
        tf.keras.layers.Dense(1,  activation="linear")
    ])
    #optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    model.compile(loss="mse", optimizer="adam", metrics=["RootMeanSquaredError"])
    model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))


    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    mse_test, rmse_test = model.evaluate(X_test, y_test)
    X_new = X_test[:3]
    y_pred = model.predict(X_new)
    print("MSE on test set")
    print( rmse_test )
    print("Predictions on several houses")
    print( y_pred )
    print("Input shape")
    print(X_train.shape[1:])
    print( "Model Summary" )
    print( model.summary() )

regression_sequential()
# Out:
# Epoch 1/10
# 363/363 [==============================] - 2s 2ms/step - loss: 130.3143 - root_mean_squared_error: 11.4155 - val_loss: 11.9323 - val_root_mean_squared_error: 3.4543
# Epoch 2/10
# 363/363 [==============================] - 1s 2ms/step - loss: 2.2458 - root_mean_squared_error: 1.4986 - val_loss: 9.3187 - val_root_mean_squared_error: 3.0527
# Epoch 3/10
# 363/363 [==============================] - 1s 2ms/step - loss: 5.0764 - root_mean_squared_error: 2.2531 - val_loss: 7.0712 - val_root_mean_squared_error: 2.6592
# Epoch 4/10
# 363/363 [==============================] - 1s 2ms/step - loss: 9.1191 - root_mean_squared_error: 3.0198 - val_loss: 8.1471 - val_root_mean_squared_error: 2.8543
# Epoch 5/10
# 363/363 [==============================] - 1s 2ms/step - loss: 6.6135 - root_mean_squared_error: 2.5717 - val_loss: 6.2557 - val_root_mean_squared_error: 2.5011
# Epoch 6/10
# 363/363 [==============================] - 1s 2ms/step - loss: 17.3476 - root_mean_squared_error: 4.1650 - val_loss: 7.1247 - val_root_mean_squared_error: 2.6692
# Epoch 7/10
# 363/363 [==============================] - 1s 2ms/step - loss: 3.8604 - root_mean_squared_error: 1.9648 - val_loss: 110.0309 - val_root_mean_squared_error: 10.4896
# Epoch 8/10
# 363/363 [==============================] - 1s 2ms/step - loss: 7.0922 - root_mean_squared_error: 2.6631 - val_loss: 4.9295 - val_root_mean_squared_error: 2.2202
# Epoch 9/10
# 363/363 [==============================] - 1s 3ms/step - loss: 67.4818 - root_mean_squared_error: 8.2147 - val_loss: 5.0990 - val_root_mean_squared_error: 2.2581
# Epoch 10/10
# 363/363 [==============================] - 1s 3ms/step - loss: 1.5316 - root_mean_squared_error: 1.2376 - val_loss: 4.0502 - val_root_mean_squared_error: 2.0125
# 162/162 [==============================] - 0s 1ms/step - loss: 1.1753 - root_mean_squared_error: 1.0841
# WARNING:tensorflow:5 out of the last 3130 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff0f4938430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 70ms/step
# MSE on test set
# 1.0841127634048462
# Predictions on several houses
# [[1.883661 ]
#  [2.165384 ]
#  [2.5283678]]
# Input shape
# (8,)
# Model Summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 8)                17
#  n)
#
#  dense (Dense)               (None, 30)                270
#
#  dense_1 (Dense)             (None, 30)                930
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,248
# Trainable params: 1,231
# Non-trainable params: 17
# _________________________________________________________________
# None

# %% [markdown]
# # Regression Example with MLP using Functional Model

# %% [markdown]
# Same regression architecture as before but this time using the functional model.

# %%
# extra code – reset the name counters and make the code reproducible
tf.keras.backend.clear_session()
tf.random.set_seed(42)

def regression_functional():
    #=====================================================#
    # Load data, load and split the California housing dataset, like earlier
    #=====================================================#
    housing = fetch_california_housing()
    X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

    #=====================================================#
    # Create model
    #=====================================================#
    input_        = tf.keras.layers.Input(shape=X_train.shape[1:])
    norm_layer    = tf.keras.layers.Normalization()
    hidden1_layer = tf.keras.layers.Dense(30, activation="relu")
    hidden2_layer = tf.keras.layers.Dense(30, activation="relu")
    output_layer  = tf.keras.layers.Dense(1,  activation="linear")

    norm_output    = norm_layer(input_)
    hidden1_output = hidden1_layer(norm_output)
    hidden2_output = hidden2_layer(hidden1_output)
    output = output_layer(hidden2_output)
    model = tf.keras.Model(inputs=[input_], outputs=[output])

    model.compile(loss="mse", optimizer="adam", metrics=["RootMeanSquaredError"])
    model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))


    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    mse_test, rmse_test = model.evaluate(X_test, y_test)
    X_new = X_test[:3]
    y_pred = model.predict(X_new)
    print("MSE on test set")
    print( rmse_test )
    print("Predictions on several houses")
    print( y_pred )
    print("Input shape")
    print(X_train.shape[1:])
    print( "Model Summary" )
    print( model.summary() )

regression_functional()
# Out:
# Epoch 1/10
# 363/363 [==============================] - 2s 2ms/step - loss: 106.9699 - root_mean_squared_error: 10.3426 - val_loss: 9.0564 - val_root_mean_squared_error: 3.0094
# Epoch 2/10
# 363/363 [==============================] - 1s 2ms/step - loss: 2.0275 - root_mean_squared_error: 1.4239 - val_loss: 5.9845 - val_root_mean_squared_error: 2.4463
# Epoch 3/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.7299 - root_mean_squared_error: 1.3153 - val_loss: 3.5131 - val_root_mean_squared_error: 1.8743
# Epoch 4/10
# 363/363 [==============================] - 1s 3ms/step - loss: 1.7803 - root_mean_squared_error: 1.3343 - val_loss: 1.8990 - val_root_mean_squared_error: 1.3780
# Epoch 5/10
# 363/363 [==============================] - 1s 3ms/step - loss: 1.3320 - root_mean_squared_error: 1.1541 - val_loss: 1.7903 - val_root_mean_squared_error: 1.3380
# Epoch 6/10
# 363/363 [==============================] - 1s 2ms/step - loss: 4.6497 - root_mean_squared_error: 2.1563 - val_loss: 1.1185 - val_root_mean_squared_error: 1.0576
# Epoch 7/10
# 363/363 [==============================] - 1s 2ms/step - loss: 0.9910 - root_mean_squared_error: 0.9955 - val_loss: 6.0156 - val_root_mean_squared_error: 2.4527
# Epoch 8/10
# 363/363 [==============================] - 1s 2ms/step - loss: 3.3724 - root_mean_squared_error: 1.8364 - val_loss: 1.0567 - val_root_mean_squared_error: 1.0280
# Epoch 9/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.7825 - root_mean_squared_error: 1.3351 - val_loss: 3.1842 - val_root_mean_squared_error: 1.7844
# Epoch 10/10
# 363/363 [==============================] - 1s 2ms/step - loss: 3.6244 - root_mean_squared_error: 1.9038 - val_loss: 1.8719 - val_root_mean_squared_error: 1.3682
# 162/162 [==============================] - 0s 1ms/step - loss: 1.8471 - root_mean_squared_error: 1.3591
# WARNING:tensorflow:6 out of the last 3131 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff0f493af80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 66ms/step
# MSE on test set
# 1.3590946197509766
# Predictions on several houses
# [[0.01026431]
#  [0.6210641 ]
#  [0.9894876 ]]
# Input shape
# (8,)
# Model Summary
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8)]               0
#
#  normalization (Normalizatio  (None, 8)                17
#  n)
#
#  dense (Dense)               (None, 30)                270
#
#  dense_1 (Dense)             (None, 30)                930
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,248
# Trainable params: 1,231
# Non-trainable params: 17
# _________________________________________________________________
# None

# %% [markdown]
# # Regression with Wide and Deep Architecture using Functional Model

# %% [markdown]
# A wide and deep architecture allows simple rules to be learned (via the short path) and more complicated rules (via the deep path).  We cannot use the Sequential model to implement this architecture.  However, Tensorflow's Functional Model provides the flexibility to implement this.

# %%
# extra code – reset the name counters and make the code reproducible
tf.keras.backend.clear_session()
tf.random.set_seed(42)

def regression_wide_and_deep():
    #=====================================================#
    # Load data, load and split the California housing dataset, like earlier
    #=====================================================#
    housing = fetch_california_housing()
    X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

    #=====================================================#
    # Create model
    #=====================================================#
    input_        = tf.keras.layers.Input(shape=X_train.shape[1:])
    norm_layer    = tf.keras.layers.Normalization()
    hidden1_layer = tf.keras.layers.Dense(30, activation="relu")
    hidden2_layer = tf.keras.layers.Dense(30, activation="relu")
    concat_layer  = tf.keras.layers.Concatenate()
    output_layer  = tf.keras.layers.Dense(1,  activation="linear")

    norm_output    = norm_layer(input_)
    hidden1_output = hidden1_layer(norm_output)
    hidden2_output = hidden2_layer(hidden1_output)
    concat_output = concat_layer([norm_output, hidden2_output])
    output = output_layer(concat_output)

    model = tf.keras.Model(inputs=[input_], outputs=[output])

    model.compile(loss="mse", optimizer="adam", metrics=["RootMeanSquaredError"])
    model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))


    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    mse_test, rmse_test = model.evaluate(X_test, y_test)
    X_new = X_test[:3]
    y_pred = model.predict(X_new)
    print("MSE on test set")
    print( rmse_test )
    print("Predictions on several houses")
    print( y_pred )
    print("Input shape")
    print(X_train.shape[1:])
    print( "Model Summary" )
    print( model.summary() )

regression_wide_and_deep()
# Out:
# Epoch 1/10
# 363/363 [==============================] - 2s 3ms/step - loss: 580.9323 - root_mean_squared_error: 24.1025 - val_loss: 10.3390 - val_root_mean_squared_error: 3.2154
# Epoch 2/10
# 363/363 [==============================] - 1s 2ms/step - loss: 3.3571 - root_mean_squared_error: 1.8322 - val_loss: 7.0006 - val_root_mean_squared_error: 2.6459
# Epoch 3/10
# 363/363 [==============================] - 1s 2ms/step - loss: 2.3928 - root_mean_squared_error: 1.5469 - val_loss: 3.5513 - val_root_mean_squared_error: 1.8845
# Epoch 4/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.8450 - root_mean_squared_error: 1.3583 - val_loss: 1.6096 - val_root_mean_squared_error: 1.2687
# Epoch 5/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.2874 - root_mean_squared_error: 1.1346 - val_loss: 1.7419 - val_root_mean_squared_error: 1.3198
# Epoch 6/10
# 363/363 [==============================] - 1s 2ms/step - loss: 4.6192 - root_mean_squared_error: 2.1492 - val_loss: 1.3421 - val_root_mean_squared_error: 1.1585
# Epoch 7/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.2120 - root_mean_squared_error: 1.1009 - val_loss: 4.2316 - val_root_mean_squared_error: 2.0571
# Epoch 8/10
# 363/363 [==============================] - 1s 2ms/step - loss: 6.0978 - root_mean_squared_error: 2.4694 - val_loss: 7.4668 - val_root_mean_squared_error: 2.7326
# Epoch 9/10
# 363/363 [==============================] - 1s 2ms/step - loss: 1.2238 - root_mean_squared_error: 1.1063 - val_loss: 4.2245 - val_root_mean_squared_error: 2.0554
# Epoch 10/10
# 363/363 [==============================] - 1s 2ms/step - loss: 13.2823 - root_mean_squared_error: 3.6445 - val_loss: 98.0081 - val_root_mean_squared_error: 9.8999
# 162/162 [==============================] - 0s 1ms/step - loss: 85.5459 - root_mean_squared_error: 9.2491
# 1/1 [==============================] - 0s 69ms/step
# MSE on test set
# 9.249099731445312
# Predictions on several houses
# [[ 8.969778]
#  [10.268186]
#  [10.003531]]
# Input shape
# (8,)
# Model Summary
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8)]          0           []
#
#  normalization (Normalization)  (None, 8)            17          ['input_1[0][0]']
#
#  dense (Dense)                  (None, 30)           270         ['normalization[0][0]']
#
#  dense_1 (Dense)                (None, 30)           930         ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 38)           0           ['normalization[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            39          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 1,256
# Trainable params: 1,239
# Non-trainable params: 17
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Discussuion:
#
# * What is the main difference between wide ad deep architechture and sequential model? Do you think it is the better option?

# %% [markdown]
# # Saving and Restoring Models

# %% [markdown]
# Training typically takes much, much longer than using the model to make predictions.  Common work flow is to train the model once and then use it to make predictions for weeks or months (even years).  How often we re-train depends on how often the data is changing (e.g. mode trained from ten years ago for housing prices is likely poor to predict on housing prices this year).
#
# After training, we would like to save the model.  Then later we can restore it to make predictions.  There are many parts of the model to save, though, the most important part are the learned weights.  Tensorflow lets us save models in several formats, we choose JSON format here.

# %%
# extra code – delete the directory, in case it already exists
import shutil
shutil.rmtree("my_keras_model", ignore_errors=True)

tf.random.set_seed(42)

def create_model():
    #=====================================================#
    # Load data, load and split the California housing dataset, like earlier
    #=====================================================#
    housing = fetch_california_housing()
    X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

    #=====================================================#
    # Create model
    #=====================================================#
    input_        = tf.keras.layers.Input(shape=X_train.shape[1:])
    norm_layer    = tf.keras.layers.Normalization()
    hidden1_layer = tf.keras.layers.Dense(30, activation="relu")
    hidden2_layer = tf.keras.layers.Dense(30, activation="relu")
    concat_layer  = tf.keras.layers.Concatenate()
    output_layer  = tf.keras.layers.Dense(1,  activation="linear")

    norm_output    = norm_layer(input_)
    hidden1_output = hidden1_layer(norm_output)
    hidden2_output = hidden2_layer(hidden1_output)
    concat_output = concat_layer([norm_output, hidden2_output])
    output = output_layer(concat_output)

    model = tf.keras.Model(inputs=[input_], outputs=[output])

    model.compile(loss="mse", optimizer="adam", metrics=["RootMeanSquaredError"])
    model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))

    return model

def evaluate_model( model ):
    #=====================================================#
    # Load data, load and split the California housing dataset, like earlier
    #=====================================================#
    housing = fetch_california_housing()
    X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    mse_test, rmse_test = model.evaluate(X_test, y_test)
    X_new = X_test[:3]
    y_pred = model.predict(X_new)
    print("MSE on test set")
    print( rmse_test )
    print("Predictions on several houses")
    print( y_pred )
    print("Input shape")
    print(X_train.shape[1:])
    print( "Model Summary" )
    print( model.summary() )


#=====================================================#
# Save model
#=====================================================#
model = create_model()
model.save("my_keras_model", save_format="h5")

#=====================================================#
# Sometime later, restore model
#=====================================================#
# extra code – show the contents of the my_keras_model/ directory
for path in sorted(Path("my_keras_model").glob("**/*")):
    print(path)
model = tf.keras.models.load_model("my_keras_model")
evaluate_model(model)
# Out:
# Epoch 1/10
# 363/363 [==============================] - 5s 5ms/step - loss: 250.4462 - root_mean_squared_error: 15.8255 - val_loss: 51.7507 - val_root_mean_squared_error: 7.1938
# Epoch 2/10
# 363/363 [==============================] - 1s 4ms/step - loss: 3.9711 - root_mean_squared_error: 1.9928 - val_loss: 29.0763 - val_root_mean_squared_error: 5.3922
# Epoch 3/10
# 363/363 [==============================] - 2s 5ms/step - loss: 2.2128 - root_mean_squared_error: 1.4876 - val_loss: 1.6821 - val_root_mean_squared_error: 1.2970
# Epoch 4/10
# 363/363 [==============================] - 1s 4ms/step - loss: 1.0940 - root_mean_squared_error: 1.0459 - val_loss: 2.8120 - val_root_mean_squared_error: 1.6769
# Epoch 5/10
# 363/363 [==============================] - 1s 4ms/step - loss: 1.0542 - root_mean_squared_error: 1.0267 - val_loss: 1.5714 - val_root_mean_squared_error: 1.2536
# Epoch 6/10
# 363/363 [==============================] - 2s 5ms/step - loss: 1.1186 - root_mean_squared_error: 1.0576 - val_loss: 3.8079 - val_root_mean_squared_error: 1.9514
# Epoch 7/10
# 363/363 [==============================] - 3s 9ms/step - loss: 0.9130 - root_mean_squared_error: 0.9555 - val_loss: 3.5044 - val_root_mean_squared_error: 1.8720
# Epoch 8/10
# 363/363 [==============================] - 2s 4ms/step - loss: 1.3965 - root_mean_squared_error: 1.1818 - val_loss: 2.1674 - val_root_mean_squared_error: 1.4722
# Epoch 9/10
# 363/363 [==============================] - 1s 3ms/step - loss: 1.0032 - root_mean_squared_error: 1.0016 - val_loss: 3.0951 - val_root_mean_squared_error: 1.7593
# Epoch 10/10
# 363/363 [==============================] - 1s 3ms/step - loss: 1.5177 - root_mean_squared_error: 1.2319 - val_loss: 15.7774 - val_root_mean_squared_error: 3.9721
# 162/162 [==============================] - 0s 1ms/step - loss: 10.0943 - root_mean_squared_error: 3.1772
# 1/1 [==============================] - 0s 65ms/step
# MSE on test set
# 3.177156686782837
# Predictions on several houses
# [[-1.2178786 ]
#  [-0.84484357]
#  [ 1.2141455 ]]
# Input shape
# (8,)
# Model Summary
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 8)]          0           []
#
#  normalization_2 (Normalization  (None, 8)           17          ['input_3[0][0]']
#  )
#
#  dense_6 (Dense)                (None, 30)           270         ['normalization_2[0][0]']
#
#  dense_7 (Dense)                (None, 30)           930         ['dense_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 38)           0           ['normalization_2[0][0]',
#                                                                   'dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 1)            39          ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 1,256
# Trainable params: 1,239
# Non-trainable params: 17
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Overfitting and Early Stopping

# %% [markdown]
# Overfitting occurs when the training loss continues to decline while the validation loss starts to increase.  Overfitting is highly undesirable as an overfit model only works well on the training data and poorly on unseen data!  One way to address is to detect when this occurs and "stop early".  Tensorflow provides a callback function capability that can be called when training, epoch, or batch has started/stopped.  An early stopping callback is provided that checks at the end of each epoch whether the validation loss is getting any better.  If not, it will stop training and use the best model so far (the best model is the one with the lowest validation loss).  This has two significant advantages
#
# * Saves significant computational resources (can set epochs to high values)
# * Mitigates overfitting
#
# The figure below is from the same figure from Fashion MNIST but using 150 epochs.  As can be seen, after about 30-40 epochs, the model begins to perform worse on the validation set.
#
# There are other approaches to address overfitting.  A common approach is "regularization" that applies a penalty to the loss function for overfitting.  You will see various penalties in Tensorflow's fit function (e.g. l2 and l1 are the most typical).

# %%
def early_stopping_example():
    #=====================================================#
    # Load data, will be numpy arrays
    #=====================================================#
    fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
    (X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
    X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
    X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
    # Scale down pixel values to float in [0.0,1.0]
    X_train, X_valid, X_test = X_train / 255.0, X_valid / 255.0, X_test / 255.0

    #show_image(X_train[0])

    class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

    #checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_checkpoints", save_weights_only=True)
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
    #=====================================================#
    # Create model
    #=====================================================#
    tf.random.set_seed(42)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape=[28, 28]))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(300, activation="relu"))
    model.add(tf.keras.layers.Dense(100, activation="relu"))
    model.add(tf.keras.layers.Dense(10, activation="softmax"))

    num_epochs = 150
    model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])
    history = model.fit(X_train, y_train, epochs=num_epochs, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])
    #print(history.params)
    show_history( history, num_epochs )


    #=====================================================#
    # Evaluate, predict (more generally evaluate), prob because BinaryCrossentropy
    #=====================================================#
    print( model.evaluate(X_test, y_test) )
    X_new = X_test[:10]
    y_new = y_test[:10]
    y_proba = model.predict(X_new)
    y_proba.round(2)
    y_pred = y_proba.argmax(axis=-1)
    #print(np.array(class_names)[y_pred]) # print what was predicted
    #show_predicted(X_new, y_new, class_names)


    #=====================================================#
    # Understanding, visualize model predictions
    #=====================================================#
    # basic way to visualize the model
    print( "Model Summary" )
    print( model.summary() )
early_stopping_example()
# Out:
# Epoch 1/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.7114 - accuracy: 0.7682 - val_loss: 0.5020 - val_accuracy: 0.8292
# Epoch 2/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4869 - accuracy: 0.8307 - val_loss: 0.4597 - val_accuracy: 0.8324
# Epoch 3/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.4412 - accuracy: 0.8447 - val_loss: 0.4224 - val_accuracy: 0.8520
# Epoch 4/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.4167 - accuracy: 0.8534 - val_loss: 0.3940 - val_accuracy: 0.8620
# Epoch 5/150
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.3958 - accuracy: 0.8608 - val_loss: 0.3897 - val_accuracy: 0.8594
# Epoch 6/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3791 - accuracy: 0.8647 - val_loss: 0.3905 - val_accuracy: 0.8632
# Epoch 7/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3665 - accuracy: 0.8694 - val_loss: 0.3685 - val_accuracy: 0.8686
# Epoch 8/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3549 - accuracy: 0.8732 - val_loss: 0.3697 - val_accuracy: 0.8654
# Epoch 9/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3441 - accuracy: 0.8773 - val_loss: 0.3455 - val_accuracy: 0.8750
# Epoch 10/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.3338 - accuracy: 0.8805 - val_loss: 0.3480 - val_accuracy: 0.8750
# Epoch 11/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3253 - accuracy: 0.8829 - val_loss: 0.3625 - val_accuracy: 0.8680
# Epoch 12/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3177 - accuracy: 0.8858 - val_loss: 0.3442 - val_accuracy: 0.8768
# Epoch 13/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3101 - accuracy: 0.8899 - val_loss: 0.3269 - val_accuracy: 0.8840
# Epoch 14/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3030 - accuracy: 0.8917 - val_loss: 0.3322 - val_accuracy: 0.8790
# Epoch 15/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2972 - accuracy: 0.8941 - val_loss: 0.3343 - val_accuracy: 0.8810
# Epoch 16/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2901 - accuracy: 0.8963 - val_loss: 0.3277 - val_accuracy: 0.8786
# Epoch 17/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2850 - accuracy: 0.8980 - val_loss: 0.3313 - val_accuracy: 0.8808
# Epoch 18/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2792 - accuracy: 0.9001 - val_loss: 0.3202 - val_accuracy: 0.8850
# Epoch 19/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2741 - accuracy: 0.9013 - val_loss: 0.3541 - val_accuracy: 0.8638
# Epoch 20/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2692 - accuracy: 0.9031 - val_loss: 0.3192 - val_accuracy: 0.8816
# Epoch 21/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2644 - accuracy: 0.9043 - val_loss: 0.3121 - val_accuracy: 0.8858
# Epoch 22/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2588 - accuracy: 0.9066 - val_loss: 0.3115 - val_accuracy: 0.8862
# Epoch 23/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2552 - accuracy: 0.9080 - val_loss: 0.3467 - val_accuracy: 0.8754
# Epoch 24/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2503 - accuracy: 0.9104 - val_loss: 0.3153 - val_accuracy: 0.8852
# Epoch 25/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2463 - accuracy: 0.9112 - val_loss: 0.3129 - val_accuracy: 0.8856
# Epoch 26/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2424 - accuracy: 0.9137 - val_loss: 0.3043 - val_accuracy: 0.8884
# Epoch 27/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2378 - accuracy: 0.9148 - val_loss: 0.3135 - val_accuracy: 0.8892
# Epoch 28/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2352 - accuracy: 0.9152 - val_loss: 0.3099 - val_accuracy: 0.8906
# Epoch 29/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2304 - accuracy: 0.9172 - val_loss: 0.3115 - val_accuracy: 0.8892
# Epoch 30/150
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.2269 - accuracy: 0.9194 - val_loss: 0.3085 - val_accuracy: 0.8888
# Epoch 31/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2224 - accuracy: 0.9201 - val_loss: 0.3183 - val_accuracy: 0.8888
# Epoch 32/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2201 - accuracy: 0.9212 - val_loss: 0.3028 - val_accuracy: 0.8910
# Epoch 33/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2168 - accuracy: 0.9217 - val_loss: 0.3232 - val_accuracy: 0.8864
# Epoch 34/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2125 - accuracy: 0.9238 - val_loss: 0.3086 - val_accuracy: 0.8906
# Epoch 35/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2085 - accuracy: 0.9250 - val_loss: 0.2988 - val_accuracy: 0.8944
# Epoch 36/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.2059 - accuracy: 0.9260 - val_loss: 0.2966 - val_accuracy: 0.8938
# Epoch 37/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2031 - accuracy: 0.9271 - val_loss: 0.3010 - val_accuracy: 0.8946
# Epoch 38/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1999 - accuracy: 0.9274 - val_loss: 0.3115 - val_accuracy: 0.8898
# Epoch 39/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1970 - accuracy: 0.9297 - val_loss: 0.2972 - val_accuracy: 0.8920
# Epoch 40/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1930 - accuracy: 0.9307 - val_loss: 0.3022 - val_accuracy: 0.8922
# Epoch 41/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1908 - accuracy: 0.9318 - val_loss: 0.3044 - val_accuracy: 0.8946
# Epoch 42/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1876 - accuracy: 0.9327 - val_loss: 0.3180 - val_accuracy: 0.8840
# Epoch 43/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1844 - accuracy: 0.9345 - val_loss: 0.3494 - val_accuracy: 0.8866
# Epoch 44/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1819 - accuracy: 0.9353 - val_loss: 0.3044 - val_accuracy: 0.8932
# Epoch 45/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1794 - accuracy: 0.9357 - val_loss: 0.2961 - val_accuracy: 0.8966
# Epoch 46/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1766 - accuracy: 0.9362 - val_loss: 0.3116 - val_accuracy: 0.8928
# Epoch 47/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1735 - accuracy: 0.9378 - val_loss: 0.3065 - val_accuracy: 0.8952
# Epoch 48/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1709 - accuracy: 0.9395 - val_loss: 0.3181 - val_accuracy: 0.8888
# Epoch 49/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1676 - accuracy: 0.9412 - val_loss: 0.3085 - val_accuracy: 0.8938
# Epoch 50/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1656 - accuracy: 0.9406 - val_loss: 0.3118 - val_accuracy: 0.8928
# Epoch 51/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1623 - accuracy: 0.9429 - val_loss: 0.3053 - val_accuracy: 0.8918
# Epoch 52/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1596 - accuracy: 0.9430 - val_loss: 0.3081 - val_accuracy: 0.8936
# Epoch 53/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1582 - accuracy: 0.9439 - val_loss: 0.3158 - val_accuracy: 0.8934
# Epoch 54/150
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.1553 - accuracy: 0.9452 - val_loss: 0.3118 - val_accuracy: 0.8926
# Epoch 55/150
# 1719/1719 [==============================] - 6s 4ms/step - loss: 0.1526 - accuracy: 0.9457 - val_loss: 0.3339 - val_accuracy: 0.8922
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3251 - accuracy: 0.8895
# [0.32513681054115295, 0.8895000219345093]
# 1/1 [==============================] - 0s 57ms/step
# Model Summary
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_9 (Dense)             (None, 300)               235500
#
#  dense_10 (Dense)            (None, 100)               30100
#
#  dense_11 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Discussion:
# * What each epoch trying to do?
# * What is the value of running less or more epochs?
# * Is more epochs always better?
